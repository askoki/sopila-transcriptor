# %%
import os
import sys
# path to settings
sys.path.insert(0, os.path.split(os.getcwd())[0])
from settings import REAL_DATA_PREDICTIONS, CUT_DIR
from random import randint
import h5py
from sty import fg, bg, rs


def get_colors():
    class_labels = os.listdir(CUT_DIR)
    class_labels.sort()

    COLORS = {}
    for i, label in enumerate(class_labels):
        COLORS[label] = '%s%s %s %s%s' % (bg(randint(0, 254)), fg.black, label, fg.rs, bg.rs)

    return COLORS


def format_output(predictions_list, colors_dict):
    formated_string = ''

    for prediction in predictions_list:
        formated_string += colors_dict[prediction]

    return formated_string


colors_dict = get_colors()
for filename in os.listdir(REAL_DATA_PREDICTIONS):
    if not 'nota' in filename:
        continue
    print("Filename: %s" % (filename))
    
    file = h5py.File(os.path.join(REAL_DATA_PREDICTIONS, filename), 'r')
    print(format_output(file['predictions'].value, colors_dict))
    print("\n\n")
# Out:
# Filename: nota_za_slozit_sopile_1.hdf5
#  v3  vv_m0v2  vv_m0v2  vv_m0v2  m0  vv_m0v5  v0  vv_m0v2  v0  v0  vv_m0v2  vv_m0v2  vv_m3v2  v0  v2  v0  vv_m0v2  vv_m4v2  v0  m1  m1  m1  vv_silence  vv_silence  m1  vv_silence  vv_silence  vv_m1v2  vv_silence  v3  vv_silence  m1  m1  vv_silence  m1  vv_m1v2  vv_m0v3  m0  m0  m0  vv_m0v3  vv_m0v3  m0  vv_m0v0  m0  m0  m0  v3  vv_m0v3  m0  m0  vv_m0v0  v3  v3  vv_m0v5  m2  vv_m2v5  m2  m2  m2  vv_m2v5  m2  m2  v3  vv_m2v0  v3  m2  vv_m2v2  vv_m2v2  vv_m2v5  m2  vv_m2v5  m2  v3  vv_m1v5  m1  vv_m1v2  vv_m1v0  vv_m1v0  vv_m1v5  m1  v3  v3  vv_m1v0  m1  v3  v3  m1  v3  v3  vv_m1v0  m1  m1  m1  v3  v0  vv_m3v5  vv_m3v0  vv_m3v5  vv_m3v5  m3  vv_m3v5  vv_m3v5  vv_m3v0  vv_m3v2  m3  vv_m3v0  vv_m3v0  vv_m3v4  vv_m3v0  vv_m3v1  vv_m3v2  vv_m3v0  m2  vv_m2v5  v0  v0  v3  v3  vv_m2v0  vv_m2v5  vv_m2v0  vv_m2v5  vv_m2v5  v3  m2  vv_m2v5  vv_m2v5  vv_m2v0  v3  vv_m2v5  vv_m2v5  vv_m3v5  v0  v0  vv_m4v1  v0  v3  vv_m4v2  vv_m5v2  v0  vv_m4v2  vv_m4v2  vv_m4v5  v3  vv_m4v5  v3  v0  v0  v0  v0  vv_m4v2  vv_m4v2  vv_m0v0  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v0  m3  vv_m3v0  v0  vv_m3v0  m3  vv_m3v5  m3  vv_m3v2  vv_m3v0  m3  vv_m3v5  vv_m3v0  vv_m3v0  vv_m3v5  vv_m3v5  v3  m3  vv_m3v0  vv_m4v5  vv_m3v1  vv_m3v2  vv_m3v5  vv_m3v5  vv_silence  v3  vv_m0v0  vv_m3v5  v0  v0  v3  v3  v3  v3  v3  v3  v3  v3  v3  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  v3  vv_silence  v3  v3  v0  v0  v0  v3  v3  v3  v3  v3  v3  v3  vv_m5v2  vv_m3v5  v3  v3  v3  m5  v0  vv_m4v5  v3  v3  v3  v3  vv_m4v2  vv_m5v0  vv_m4v5  m5  v0  v3  v0  vv_m5v2  v3  v0  vv_m3v5  vv_m3v5  vv_m4v2  vv_m3v2  vv_m3v2  vv_m3v5  vv_m3v2  vv_m3v5  vv_m3v5  vv_m3v5  vv_m0v5  v0  vv_m3v2  vv_m4v5  vv_m3v2  vv_m3v2  vv_m3v2  vv_m3v5  vv_m3v5  vv_m3v2  v2  vv_m3v5  vv_m3v5  vv_m3v5  vv_m2v5  m2  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v2  vv_m3v5  v3  vv_m2v5  vv_m1v5  vv_m1v5  v3  vv_m1v5  vv_m1v5  v0  m1  v3  v0  v3  v3  v3  vv_m1v5  vv_m0v2  vv_m1v5  v0  vv_m1v5  v3  vv_m1v5  v0  v0  v3  vv_m1v4  vv_m0v3  vv_m0v5  v3  v0  vv_m0v0  v0  v3  vv_m0v0  vv_m0v5  v3  v0  v3  v3  vv_m0v3  vv_m0v0  v3  vv_m0v3  v3  v0  vv_m0v0  vv_m0v0  v0  vv_m0v3  v0  v3  v0  vv_m0v2  v3  v0  vv_m1v2  v3  v0  v0  v3  v0  v0  v0  v0  v0  v0  v0  v0  v3  v3  v3  v3  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  v3  v3  v3  vv_m5v1  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v0  vv_m2v4  vv_m2v5  vv_m2v0  vv_m3v4  vv_m4v5  vv_m2v0  vv_m3v4  vv_m2v4  vv_m2v0  vv_m3v4  vv_m3v4  vv_m2v5  vv_m3v4  vv_m3v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m3v4  vv_m3v4  vv_m2v5  vv_m2v0  vv_m2v4  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v1  vv_m3v5  vv_m3v4  vv_m3v4  vv_m2v5  vv_m3v4  vv_m2v5  vv_m2v5  vv_m3v4  vv_m3v5  vv_m3v4  vv_m3v4  vv_m3v5  vv_m2v5  vv_m2v5  vv_m3v5  vv_m2v5  vv_m3v4  vv_m2v5  vv_m2v5  vv_m3v4  vv_m2v5  vv_m2v5  vv_m3v5  vv_m3v4  vv_m3v4  vv_m3v5  vv_m3v4  v5  vv_m1v1  v5  v5  vv_m4v5  vv_m3v4  vv_m3v4  vv_m3v5  vv_m3v4  vv_m3v5  vv_m3v4  vv_m3v4  vv_m3v5  vv_m3v5  vv_m3v4  vv_m3v5  vv_m3v0  vv_m3v4  vv_m3v5  vv_m3v5  vv_m2v5  vv_m3v4  vv_m3v1  vv_m3v5  vv_m0v5  vv_m3v4  vv_m2v5  vv_m2v5  vv_m3v5  vv_m3v5  vv_m3v4  vv_m3v4  vv_m3v5  vv_m3v4  vv_m3v4  vv_m3v0  vv_m2v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v1  vv_m3v4  vv_m3v4  vv_m3v5  vv_m2v5  vv_m3v4  vv_m3v5  vv_m3v5  vv_m3v4  vv_m3v4  vv_m3v5  vv_m3v4  vv_m3v5  vv_m2v1  vv_m2v5  vv_m2v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v1  vv_m0v5  vv_m3v5  vv_m2v5  vv_m2v5  vv_m3v4  vv_m2v5  vv_m2v5  vv_m3v4  vv_m2v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m2v5  vv_m2v ...
#
#
#
# Filename: nota_za_slozit_sopile_2.hdf5
#  vv_m2v0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  vv_m0v2  m0  m0  m0  m0  m0  vv_m0v2  m0  m0  m0  m0  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  m1  v3  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m1  m1  m2  m2  m2  m2  m2  m2  vv_m2v2  m2  m2  m2  m2  v0  vv_m2v5  vv_m3v5  v3  m2  vv_m2v5  m2  m2  m2  m2  m2  m2  vv_m2v0  vv_m3v5  m2  m2  vv_m3v2  vv_m3v5  v3  vv_m2v5  m2  m2  vv_m2v5  vv_m3v5  m2  vv_m3v5  vv_m2v5  vv_m3v5  vv_m2v0  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v5  m2  vv_m3v5  vv_m3v5  vv_m2v1  vv_m2v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m2v5  m2  vv_m3v5  m2  v3  v0  m2  m2  m2  m2  m2  m2  m2  m2  m2  vv_m1v0  v3  vv_silence  v3  vv_m1v0  v3  m1  vv_m1v0  m1  m1  m1  m1  m1  m1  vv_m1v5  vv_silence  v3  vv_m0v2  vv_m1v5  v3  vv_m1v5  v3  vv_m1v5  v3  vv_m3v0  vv_m3v0  v0  vv_m1v4  vv_m3v2  vv_m3v5  vv_m3v2  v0  vv_m3v5  vv_m3v0  vv_m3v2  vv_m3v2  vv_m3v5  vv_m3v2  vv_m3v5  vv_m0v5  vv_m3v5  vv_m3v2  v0  m3  v0  vv_m3v2  m3  vv_m3v5  vv_m3v0  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v2  vv_m3v5  vv_m3v5  v3  vv_m3v5  vv_m3v5  vv_m3v2  vv_m3v2  vv_m3v2  vv_m3v5  vv_m3v5  v0  vv_m4v2  v3  m5  vv_m5v2  vv_m0v2  v0  v0  m5  m5  vv_m5v2  vv_m5v2  vv_m5v2  vv_m5v0  v0  vv_m5v2  v0  vv_m4v5  vv_m5v5  v0  v0  m5  vv_m0v2  m4  v0  vv_m3v5  vv_m3v0  vv_m3v2  vv_m3v5  v3  v3  vv_m3v5  vv_m3v2  vv_m3v0  v0  v0  vv_m3v2  m3  vv_m3v0  vv_m3v5  vv_m3v2  vv_m3v0  vv_m3v2  vv_m3v0  v0  m3  vv_m3v5  vv_m3v2  vv_m3v2  v0  vv_m3v5  m3  vv_m3v5  vv_m3v0  v0  v0  vv_m3v2  vv_m3v0  m3  m3  m3  m3  m3  m3  m4  m4  m3  v3  m0  m4  v0  v0  v0  v0  v3  vv_silence  v3  v3  v0  v0  v0  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  vv_silence  v3  v3  v3  v0  v3  v3  v0  v0  vv_m5v0  v0  m4  m4  m4  m4  v0  vv_silence  m4  v0  vv_m4v5  m4  m4  vv_m5v2  v0  vv_silence  m4  vv_m4v2  m4  vv_m4v2  m4  v0  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v2  vv_m3v5  vv_m3v2  v0  vv_m3v2  m3  vv_m3v2  vv_m3v5  v0  vv_m3v2  vv_m3v5  vv_m0v2  vv_m3v2  vv_m3v1  vv_m3v5  vv_m3v2  vv_m3v1  vv_m3v5  v3  vv_m3v5  vv_m2v0  vv_m3v5  vv_m3v1  v3  vv_m2v2  m2  vv_m3v5  vv_m3v5  vv_m2v0  vv_m3v5  vv_m3v5  v3  vv_m3v5  vv_m3v5  vv_m3v2  vv_m2v5  vv_m3v5  vv_m3v5  v3  m1  v3  v3  vv_m1v5  m1  v3  m1  vv_m1v5  m1  m1  m1  m1  m1  vv_silence  vv_silence  m1  vv_silence  m1  m1  v0  v0  v0  vv_m0v3  v0  v3  v3  vv_m0v3  vv_m0v0  v0  v3  vv_m0v5  vv_m0v4  v3  v3  v3  v3  m0  m0  v0  v3  v0  v3  v3  vv_m0v5  v3  v3  vv_m0v0  m1  m1  vv_m0v4  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  m0  v0  v3  v0  v3  v0  v3  v3  v3  vv_silence  v3  v3  v3  v3  v0  v0  v3  v3  vv_silence  v3  v0  v4  vv_m3v5  vv_m2v5  vv_m2v5  v4  vv_m2v5  vv_m2v5  vv_m2v5  vv_m3v4  vv_m2v4  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v1  vv_m2v4  vv_m2v4  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v1  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v2  vv_m2v1  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v1  vv_m2v4  vv_m3v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v1  vv_m2v5  vv_m2v5  vv_m2v1  vv_m2v5  vv_m2v5  vv_m3v5  vv_m3v5  vv_m2v5  vv_m2v5  vv_m2v1  vv_m2v4  vv_m2v5  vv_m2v5  vv_m3v4  vv_m3v5  v5  v5  vv_m3v5  vv_m2v4  vv_m2v5  vv_m2v1  v5  v5  v5  v5  v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m3v5  v5  vv_m3v5  v5  v5  v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m2v5  vv_m3v5  vv_m3v5  vv_m0v1  vv_m2v5  vv_m2v5  vv_m2v5  vv_m3v3  vv_m3v5  v5  vv_m2v5  vv_m2v5  vv_m2v4  vv_m2v1  vv_m2v5  vv_m2v5  vv_m3v5  vv_m3v4  vv_m3v5  vv_m0v5  vv_m3v3  v5  vv_m4v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m3v5  vv_m3v0  v5  vv_m3v5  vv_m0v5  vv_m4v5  vv_m3v1  vv_m2v5  vv_m2v5  vv_m2v5  vv_m2v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m3v5  vv_m2v5  vv_m2v5  vv_m3v5  vv_m3v5  vv_m2v5  vv_m2v5  vv_m3v4  vv_m2v5  vv_m3v2  v5  vv_m3v5  vv_m2v5  vv_m ...
